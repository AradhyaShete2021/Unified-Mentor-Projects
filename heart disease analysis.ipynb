# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
data=pd.read_csv(r"C:\Users\ARADHYA\OneDrive\Desktop\Heart Disease data.csv")

# %%
data.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.shape       #  data have 1025 rows and 14 columns
# Out:
# (1025, 14)

# %%
data.columns  #ttotal 14 columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# # checking  null values

# %%
data.isnull()  # checking  null values
# Out:
#         age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0     False  False  False     False  False  False    False    False  False
# 1     False  False  False     False  False  False    False    False  False
# 2     False  False  False     False  False  False    False    False  False
# 3     False  False  False     False  False  False    False    False  False
# 4     False  False  False     False  False  False    False    False  False
# ...     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 1020  False  False  False     False  False  False    False    False  False
# 1021  False  False  False     False  False  False    False    False  False
# 1022  False  False  False     False  False  False    False    False  False
# 1023  False  False  False     False  False  False    False    False  False
# 1024  False  False  False     False  False  False    False    False  False
#
#       oldpeak  slope     ca   thal  target
# ...

# %%
data.isnull().sum()  # checking the mising values
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.isna().sum()    #checking the null values
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # Checking  duplicates values

# %%
data.duplicated().any()    # checking duplicate values
# Out:
# True

# %%
data=data.drop_duplicates()  # now droping the duplicates values from the dataset

# %%
data.shape   # checking how many data has been shaded after dropping the duplicates
# Out:
# (302, 14)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# ...

# %%
# age                              #age in numbers 
# sex                              # its contain  0 for male and 1 for female
# chest pain type (4 values)       #cp contains the chest pain which as 4 values 0,1,2,3 
# resting blood pressure           
# serum cholestoral in mg/dl
# fasting blood sugar > 120 mg/dl
# resting electrocardiographic results (values 0,1,2)
# maximum heart rate achieved
# exercise induced angina
# oldpeak = ST depression induced by exercise relative to rest
# the slope of the peak exercise ST segment
# number of major vessels (0-3) colored by flourosopy
# thal: 0 = normal; 1 = fixed defect; 2 = reversable defect

# %% [markdown]
# # Determining which age group in a dataset contains most data

# %%
data['age'].value_counts().to_frame()
# Out:
#      count
# age
# 58      19
# 57      17
# 54      16
# 59      14
# 52      13
# 51      12
# 44      11
# 60      11
# 56      11
# 62      11
# 41      10
# 64      10
# 67       9
# 63       9
# 42       8
# 43       8
# 65       8
# 53       8
# 61       8
# 45       8
# 55       8
# 50       7
# 46       7
# 66       7
# 48       7
# 49       5
# 47       5
# 68       4
# 70       4
# 35       4
# 39       4
# 69       3
# 40       3
# 71       3
# 37       2
# 38       2
# 34       2
# 76       1
# 29       1
# 77       1
# 74       1

# %%
data['age'].value_counts(normalize=True).to_frame()
# Out:
#      proportion
# age
# 58     0.062914
# 57     0.056291
# 54     0.052980
# 59     0.046358
# 52     0.043046
# 51     0.039735
# 44     0.036424
# 60     0.036424
# 56     0.036424
# 62     0.036424
# 41     0.033113
# 64     0.033113
# 67     0.029801
# 63     0.029801
# 42     0.026490
# 43     0.026490
# 65     0.026490
# 53     0.026490
# 61     0.026490
# 45     0.026490
# 55     0.026490
# 50     0.023179
# 46     0.023179
# 66     0.023179
# 48     0.023179
# 49     0.016556
# 47     0.016556
# 68     0.013245
# 70     0.013245
# 35     0.013245
# 39     0.013245
# 69     0.009934
# 40     0.009934
# 71     0.009934
# 37     0.006623
# 38     0.006623
# 34     0.006623
# 76     0.003311
# 29     0.003311
# 77     0.003311
# 74     0.003311

# %%
# These indicate that the majority of the age group data that has been gathered falls between 45 and 65.

# %% [markdown]
# # Computing the percentage of people who have chest pain depending on its values

# %%
data['cp'].value_counts().to_frame()
# Out:
#     count
# cp
# 0     143
# 2      86
# 1      50
# 3      23

# %%
data['cp'].value_counts(normalize=True).to_frame()
# Out:
#     proportion
# cp
# 0     0.473510
# 2     0.284768
# 1     0.165563
# 3     0.076159

# %%
# According to statistics
# 47.35% of persons report having no chest pain,
# 28% report having moderate chest pain, 
# 16% report having mild chest pain,
# and 7% report having extremely severe chest pain.

# %% [markdown]
# # checking the resting blood pressure

# %%
data['trestbps'].value_counts().to_frame()
# Out:
#           count
# trestbps
# 130          51
# 120          37
# 140          32
# 110          19
# 150          17
# 138          12
# 128          12
# 125          11
# 160          11
# 112           9
# 132           8
# 118           7
# 124           6
# 108           6
# 135           6
# 134           5
# 152           5
# 145           5
# 122           4
# 100           4
# 105           3
# 142           3
# 126           3
# 136           3
# 115           3
# 146           2
# 102           2
# 144           2
# 148           2
# 164           1
# 165           1
# 156           1
# 155           1
# 129           1
# 123           1
# 154           1
# 117           1
# 104           1
# 106           1
# 114           1
# 101           1

# %%
data['trestbps'].value_counts(normalize=True).to_frame()
# Out:
#           proportion
# trestbps
# 130         0.168874
# 120         0.122517
# 140         0.105960
# 110         0.062914
# 150         0.056291
# 138         0.039735
# 128         0.039735
# 125         0.036424
# 160         0.036424
# 112         0.029801
# 132         0.026490
# 118         0.023179
# 124         0.019868
# 108         0.019868
# 135         0.019868
# 134         0.016556
# 152         0.016556
# 145         0.016556
# 122         0.013245
# 100         0.013245
# 105         0.009934
# 142         0.009934
# 126         0.009934
# 136         0.009934
# 115         0.009934
# 146         0.006623
# 102         0.006623
# 144         0.006623
# 148         0.006623
# 164         0.003311
# 165         0.003311
# 156         0.003311
# 155         0.003311
# 129         0.003311
# 123         0.003311
# 154         0.003311
# 117         0.003311
# 104         0.003311
# 106         0.003311
# 114         0.003311
# 101         0.003311

# %%
data['trestbps'].value_counts(normalize=True)
# Out:
# trestbps
# 120    0.122517
# 130    0.119205
# 140    0.105960
# 110    0.062914
# 150    0.056291
# 138    0.039735
# 128    0.039735
# 125    0.036424
# 160    0.036424
# 112    0.029801
# 132    0.026490
# 118    0.023179
# 135    0.019868
# 108    0.019868
# 124    0.019868
# 152    0.016556
# 134    0.016556
# 145    0.016556
# 122    0.013245
# 100    0.013245
# 170    0.013245
# 115    0.009934
# 136    0.009934
# 180    0.009934
# 126    0.009934
# 142    0.009934
# 105    0.009934
# 144    0.006623
# 102    0.006623
# 94     0.006623
# 146    0.006623
# 178    0.006623
# 148    0.006623
# 174    0.003311
# 165    0.003311
# 156    0.003311
# 164    0.003311
# 172    0.003311
# 155    0.003311
# 114    0.003311
# 200    0.003311
# 154    0.003311
# 106    0.003311
# 104    0.003311
# 192    0.003311
# 129    0.003311
# 117    0.003311
# 123    0.003311
# 101    0.003311
# Name: proportion, dtype: float64

# %% [markdown]
# # plotting  histogram

# %%
data.hist(layout=(25,5),figsize=(30, 60))
plt.show()

# %%
data.skew()   # considering the range -0.80 to 0.80 to check the distribution
# Out:
# age        -0.203743
# sex        -0.786120
# cp          0.493022
# trestbps    0.716541
# chol        1.147332
# fbs         1.981201
# restecg     0.169467
# thalach    -0.532671
# exang       0.737281
# oldpeak     1.266173
# slope      -0.503247
# ca          1.295738
# thal       -0.481232
# target     -0.173691
# dtype: float64

# %%
data.kurt()
# Out:
# age        -0.527512
# sex        -1.391273
# cp         -1.183729
# trestbps    0.922996
# chol        4.542591
# fbs         1.937947
# restecg    -1.359464
# thalach    -0.062186
# exang      -1.466170
# oldpeak     1.567876
# slope      -0.629935
# ca          0.781003
# thal        0.295855
# target     -1.983008
# dtype: float64

# %% [markdown]
# #  checking for outliers

# %%
data.plot(kind='box', subplots=True, layout=(25,5), sharex=False, sharey=False,figsize=(30, 60))
plt.show()

# %%
# Based on the above analysis we can observe that the following features have outliers :
# 1) trestbps 2) chol 3)fbs 4)thalach 5)oldpeak 6)ca 7)thal

# %% [markdown]
# # Utilize the z-score method, which is standardization, to eliminate outliers

# %%
z1=stats.zscore(data['trestbps'])
z2=stats.zscore(data['chol'])
z3=stats.zscore(data['fbs'])
z4=stats.zscore(data['thalach'])
z5=stats.zscore(data['oldpeak'])
z6=stats.zscore(data['ca'])
z7=stats.zscore(data['thal'])

# %%
# We insert the computed Z-Score into the DataFrame-data
data.insert(0,'Z_Score_trestbps',list(z1),True)
data.insert(0,'Z_Score_chol',list(z2),True)
data.insert(0,'Z_Score_fbs',list(z3),True)
data.insert(0,'Z_Score_thalach',list(z4),True)
data.insert(0,'Z_Score_oldpeak',list(z5),True)
data.insert(0,'Z_Score_ca',list(z6),True)
data.insert(0,'Z_Score_thal',list(z7),True)

# %%
data.head(10)
# Out:
#    Z_Score_thal  Z_Score_ca  Z_Score_oldpeak  Z_Score_thalach  Z_Score_fbs  \
# 0      1.119967    1.274980        -0.037124         0.806035    -0.418446
# 1      1.119967   -0.714911         1.773958         0.237495     2.389793
# 2      1.119967   -0.714911         1.342748        -1.074521    -0.418446
# 3      1.119967    0.280034        -0.899544         0.499898    -0.418446
# 4     -0.513994    2.269926         0.739054        -1.905464     2.389793
# 5     -0.513994   -0.714911        -0.037124        -1.205722    -0.418446
# 6     -2.147955    2.269926         2.895104        -0.418513    -0.418446
# 7      1.119967    0.280034        -0.209608        -0.199843    -0.418446
# 8      1.119967   -0.714911        -0.209608        -0.243577    -0.418446
# 9     -0.513994    1.274980         1.860200        -1.468126    -0.418446
#
#    Z_Score_chol  Z_Score_trestbps  age  sex  cp  ...  chol  fbs  restecg  \
# ...

# %%
data.shape
# Out:
# (302, 21)

# %%
# We will filter out the extreme Z-Scores from the required columns
# After the filtering has been successfully done we will enter NaN values into the respective columns

# %%
data.loc[data['Z_Score_trestbps'] > 1.96,'trestbps'] = np.nan
data.loc[data['Z_Score_trestbps'] < -1.96,'trestbps'] = np.nan

data.loc[data['Z_Score_chol'] > 1.96, 'chol'] = np.nan
data.loc[data['Z_Score_chol'] < -1.96, 'chol'] = np.nan

data.loc[data['Z_Score_fbs'] > 1.96, 'fbs'] = np.nan
data.loc[data['Z_Score_fbs'] < -1.96, 'fbs'] = np.nan

data.loc[data['Z_Score_thalach'] > 1.96, 'thalach'] = np.nan
data.loc[data['Z_Score_thalach'] < -1.96, 'thalach'] = np.nan

data.loc[data['Z_Score_oldpeak'] > 1.96, 'oldpeak'] = np.nan
data.loc[data['Z_Score_oldpeak'] < -1.96, 'oldpeak'] = np.nan

data.loc[data['Z_Score_ca'] > 1.96, 'ca'] = np.nan
data.loc[data['Z_Score_ca'] < -1.96, 'ca'] = np.nan

data.loc[data['Z_Score_thal'] > 1.96, 'thal'] = np.nan
data.loc[data['Z_Score_thal'] < -1.96, 'thal'] = np.nan

# %%
data=data.drop(columns=['Z_Score_trestbps','Z_Score_chol','Z_Score_fbs','Z_Score_thalach',
                   'Z_Score_oldpeak','Z_Score_ca','Z_Score_thal'])

# %%
# Checking for null values inside the filtered dataset
print(data.isnull().sum())
# Out:
# age          0
# sex          0
# cp           0
# trestbps    15
# chol        11
# fbs         45
# restecg      0
# thalach     12
# exang        0
# oldpeak     17
# slope        0
# ca          24
# thal        20
# target       0
# dtype: int64

# %%
data['fbs'].value_counts()   # checking most repeated elements
# Out:
# fbs
# 0.0    257
# Name: count, dtype: int64

# %%
data['ca'].value_counts()   # checking most repeated elements
# Out:
# ca
# 0.0    175
# 1.0     65
# 2.0     38
# Name: count, dtype: int64

# %%
data['thal'].value_counts()   # checking most repeated elements
# Out:
# thal
# 2.0    165
# 3.0    117
# Name: count, dtype: int64

# %%
data.head(10)
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0        1    168.0      0      1.0
# 1   53    1   0     140.0  203.0  NaN        0    155.0      1      3.1
# 2   70    1   0     145.0  174.0  0.0        1    125.0      1      2.6
# 3   61    1   0     148.0  203.0  0.0        1    161.0      0      0.0
# 4   62    0   0     138.0  294.0  NaN        1    106.0      0      1.9
# 5   58    0   0     100.0  248.0  0.0        0    122.0      0      1.0
# 6   58    1   0     114.0  318.0  0.0        2    140.0      0      NaN
# 7   55    1   0     160.0  289.0  0.0        0    145.0      1      0.8
# 8   46    1   0     120.0  249.0  0.0        0    144.0      0      0.8
# 9   54    1   0     122.0  286.0  0.0        0    116.0      1      3.2
#
#    slope   ca  thal  target
# 0      2  2.0   3.0       0
# 1      0  0.0   3.0       0
# 2      0  0.0   3.0       0
# 3      2  1.0   3.0       0
# 4      1  NaN   2.0       0
# ...

# %%
print(data['trestbps'].median())
print(data['chol'].median())
print(data['fbs'].mode())
print(data['thalach'].median())
print(data['oldpeak'].median())
print(data['ca'].mode())
print(data['thal'].mode())
# Out:
# 130.0
# 240.0
# 0    0.0
# Name: fbs, dtype: float64
# 154.0
# 0.6
# 0    0.0
# Name: ca, dtype: float64
# 0    2.0
# Name: thal, dtype: float64

# %%
data.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps    15
# chol        11
# fbs         45
# restecg      0
# thalach     12
# exang        0
# oldpeak     17
# slope        0
# ca          24
# thal        20
# target       0
# dtype: int64

# %%
#filling the null values by median 
data['trestbps'].replace(np.nan,data['trestbps'].median(),inplace=True)
data['chol'].replace(np.nan,data['chol'].median(),inplace=True)
data['thalach'].replace(np.nan,data['thalach'].median(),inplace=True)       
data['oldpeak'].replace(np.nan,data['oldpeak'].median(),inplace=True)

# %%
#filling null values by mode
ca_mode = data['ca'].mode()[0]
data['ca'].replace(np.nan, ca_mode, inplace=True)
thal_mode = data['thal'].mode()[0]
data['thal'].replace(np.nan, thal_mode, inplace=True)
data['fbs'].fillna(1,inplace=True)

# %%
data.head(10)
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1   0     125.0  212.0  0.0        1    168.0      0      1.0
# 1   53    1   0     140.0  203.0  1.0        0    155.0      1      3.1
# 2   70    1   0     145.0  174.0  0.0        1    125.0      1      2.6
# 3   61    1   0     148.0  203.0  0.0        1    161.0      0      0.0
# 4   62    0   0     138.0  294.0  1.0        1    106.0      0      1.9
# 5   58    0   0     100.0  248.0  0.0        0    122.0      0      1.0
# 6   58    1   0     114.0  318.0  0.0        2    140.0      0      0.6
# 7   55    1   0     160.0  289.0  0.0        0    145.0      1      0.8
# 8   46    1   0     120.0  249.0  0.0        0    144.0      0      0.8
# 9   54    1   0     122.0  286.0  0.0        0    116.0      1      3.2
#
#    slope   ca  thal  target
# 0      2  2.0   3.0       0
# 1      0  0.0   3.0       0
# 2      0  0.0   3.0       0
# 3      2  1.0   3.0       0
# 4      1  0.0   2.0       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302 entries, 0 to 878
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    float64
#  4   chol      302 non-null    float64
#  5   fbs       302 non-null    float64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    float64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    float64
#  12  thal      302 non-null    float64
#  13  target    302 non-null    int64
# dtypes: float64(7), int64(7)
# memory usage: 35.4 KB

# %%
data['trestbps']=data['trestbps'].astype('int64')
data['chol']=data['chol'].astype('int64')
data['fbs']=data['fbs'].astype('int64')
data['ca']=data['fbs'].astype('int64')
data['thal']=data['thal'].astype('int64')
data['thalach']=data['thalach'].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302 entries, 0 to 878
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB

# %%
data.plot(kind='box',subplots=True, layout=(25,5), sharex=False, sharey=False, figsize=(30,60))
plt.show()
# after z-score(standardization) outlier has been removed

# %%
data.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      0.6
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
# As a result we can say that outliers has been reduced and data is clean

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
correlation=data.corr()
correlation
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.255366  0.160992  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.026026 -0.105427  0.046022
# cp       -0.063107 -0.051740  1.000000  0.068255 -0.077527  0.096018
# trestbps  0.255366 -0.026026  0.068255  1.000000  0.059322  0.110858
# chol      0.160992 -0.105427 -0.077527  0.059322  1.000000  0.033886
# fbs       0.119492  0.046022  0.096018  0.110858  0.033886  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.108284 -0.087676 -0.083081
# thalach  -0.363217 -0.036036  0.287107 -0.063571 -0.017006  0.036735
# exang     0.093216  0.143460 -0.392937 -0.002355  0.087251  0.024729
# oldpeak   0.222911  0.126059 -0.105053  0.077014 -0.006795  0.032024
# slope    -0.164124 -0.032990  0.116854 -0.040062  0.014295 -0.058654
# ca        0.119492  0.046022  0.096018  0.110858  0.033886  1.000000
# thal      0.106699  0.323934 -0.235765  0.045952  0.044211  0.029896
# ...

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(correlation, annot=True,fmt=".2f", linewidths=.5)
plt.title('Correlation heatmap')
plt.show()

# %%
data['sex'].value_counts(normalize=True)
# Out:
# sex
# 1    0.682119
# 0    0.317881
# Name: proportion, dtype: float64

# %%
data['sex'].value_counts(normalize=True).plot(kind='bar',color='green')
plt.show()

# %%
data['sex'].value_counts().plot(kind='pie',figsize=(5,6),autopct='%1.1f%%',startangle=90,shadow=True)
plt.title('sex')
plt.axis('equal')
plt.show()

# %%
# from the above analysis there are 68.21% of males  31.78% of females

# %%
data['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
# from the above analysis there are 164 yes and 138 no's

# %%
data['target'].value_counts(normalize=True)
# Out:
# target
# 1    0.543046
# 0    0.456954
# Name: proportion, dtype: float64

# %%
data['target'].value_counts(normalize=True).plot(kind='bar',color='red')
plt.show()

# %%
data['target'].value_counts().plot(kind='pie',figsize=(5,6),autopct='%1.1f%%',startangle=90,shadow=True)
plt.title('heart diseases')
plt.axis('equal')
plt.show()

# %%
# Analysis showed that 45.70% of people had cardiac disease and 54.40% did not.

# %%
data.groupby(['target'])['sex'].value_counts(normalize=True).sort_values(ascending=False).plot(kind='bar',figsize=(15,5))
plt.show()

# %%
sns.countplot(x='sex',hue='target',data=data)   # as a results females have more heart disease than males
plt.xticks([0, 1], ['Female', 'Male'])
plt.legend(labels=('No-Diseases', 'Diseases'))
plt.show()

# %%
data.groupby(['sex'])['target'].value_counts().sort_values(ascending=False).plot(kind='pie',figsize=(9,7),autopct='%1.1f%%',
                                                                                startangle=90,shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
# from the above analysis we can say that out of the total population of male arount 40 to 45% poupluation are affetcted  
# from the above population we can say that women population are more affected to the heart diseases than men

# %%
#checking what percentage of people have chestpain on the basis of values
data['cp'].value_counts().plot(kind='pie',figsize=(5,6),autopct='%1.1f%%',startangle=90,shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
# from the above analysis we have got 
# 47.4% of persons report not having chest pain,
# 28.5% report having moderate chest pain,
# 16.6% report having mild chest pain,
#  and 7.6% report having severe chest pain.

# %%
data.groupby(['cp'])['target'].value_counts().sort_values(ascending=False)
# Out:
# cp  target
# 0   0         104
# 2   1          68
# 1   1          41
# 0   1          39
# 2   0          18
# 3   1          16
# 1   0           9
# 3   0           7
# Name: count, dtype: int64

# %%
sns.countplot(x='cp',hue='target',data=data)
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
data.groupby(['cp'])['target'].value_counts().sort_values(ascending=False).plot(kind='pie',figsize=(9,7),autopct='%1.1f%%',
                                                                                startangle=90,shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
# from the analysis we can say
# 34.43% people dont have chestpain and dont have heart disease
# 22.5% people have more than moderate chestpain and have a heart disease
# 13.6% people have mild  and have heart disease
# 12.9 % people have no chestpain but have a heart diseases
# 6% people have moderate chestpain but they dont have heart diseases
# 5.3 % people have severe chestpain and have a heart disease
# 3% people have mild chest pain but dont have heart disease
# 2.3% people have severe chest pain and do not have heart disease

# %%
#Checking the resting ecg 
data['restecg'].value_counts().plot(kind='pie',figsize=(5,6),autopct='%1.1f%%',startangle=90,shadow=True)

# from the analysis 48.7% people have normal ecg
# 50% people have mild changes in ecg
#1.3 % people have severe changes in ecg
# Out:
# <Axes: ylabel='count'>

# %%
plt.plot(figsize=(15,10))
sns.histplot(data=data,x='age',hue='target',kde=True)
plt.title('Distribution of Age by Target')
plt.show()                                              # graphs shows Distribution of Age by Target
plt.show()

# %%
plt.plot(figsize=(15,10))
sns.histplot(data=data,x='age',hue='cp',kde=True)
plt.title('Distribution of Age by ChestPain')      # graphs shows Distribution of Age by Chestpain
plt.show()

# %%
plt.plot(figsize=(10, 6))
sns.histplot(data=data, x='age', hue='fbs', kde=True)
plt.title('Distribution of Age by FBS over 120')            #graphs show Distribution of Age by Fasting blood Sugar over 120
plt.show()

# %%
plt.figure(figsize=(10, 6))                                        # graph shows level of max heartrate with respect to age 
sns.scatterplot(data=data, x='age', y='thalach', hue='thalach')
plt.title('Age & Max heart rate')
plt.xlabel('Age')
plt.ylabel('Max HR')
plt.show()

# %%
plt.plot(figsize=(10,6))                                       # graph shows level of cholestrol with respect to age 
sns.scatterplot(data=data,x='age',y='chol',hue='chol') 
plt.title('Age & Cholestrol')
plt.xlabel('Age')
plt.ylabel('Cholestrol')
plt.show()

# %%
plt.plot(figsize=(10,6))                                  # graphs shows age and Excerise induced Angina 
sns.histplot(data=data,x='age',hue='exang',kde=True)
plt.title('Age & Excerise Induced Angina')
plt.show()

# %%
plt.plot(figsize=(10,6))                                  # graphs shows age and Resting Electrocardiographic  results 
sns.histplot(data=data,x='age',hue='restecg',kde=True)    
plt.title('Age & resting electrocardiographic results')
plt.show()

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   0     3       0
# 1   1     3       0
# 2   0     3       0
# 3   0     3       0
# 4   1     2       0

# %%
sns.countplot(x='sex',hue='fbs',data=data)    # garph shows fasting blood sugar by sex(males=1, females=0)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex',hue='cp',data=data)    # shows mild, moderate , severe & no chestpain with respect to sex
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
data.groupby(['sex'])['restecg'].value_counts().sort_values(ascending=False).plot(kind='pie',figsize=(15,7),autopct='%1.1f%%',
                                                                                startangle=90,shadow=True)
# shows the resting ecg with respect to sex
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data=data,x='sex',hue='restecg')  # counting the resting ecg(0 for normal ecg,1 for mild or moderate , 
#2 for sereve changes  with respect to sex(males =1 . females=0)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(10, 6))                                         
sns.scatterplot(data=data, x='age', y='oldpeak', hue='oldpeak')
plt.title('Age & ST Depression Induced by Exercise Relative to Rest(oldpeak)')
plt.xlabel('Age')
plt.ylabel('ST depression induced by exercise relative to rest')
plt.show()

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   0     3       0
# 1   1     3       0
# 2   0     3       0
# 3   0     3       0
# 4   1     2       0

# %%
data['ca'].value_counts()
# Out:
# ca
# 0    257
# 1     45
# Name: count, dtype: int64

# %%
data['ca'].value_counts(normalize=True).sort_values(ascending=False).plot(kind='pie',figsize=(10,6),autopct='%1.1f%%',
                                                                        startangle=90,shadow=True)
#   number of major vessels (0-3) colored by flourosopy
# Out:
# <Axes: ylabel='proportion'>

# %%
sns.countplot(data=data,x='ca',hue='target')   #  number of major vessels (0-3) colored by flourosopy
# Out:
# <Axes: xlabel='ca', ylabel='count'>

# %%
data.groupby(['ca'])['target'].value_counts().sort_values(ascending=False).plot(kind='pie',figsize=(15,7),autopct='%1.1f%%',
                                                                                startangle=90,shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
# From the above analysis number of major vessels (0-3) colored by flourosopy 
# 46.7% people have zero major vessel seen but they have heart disease
# 38.4% people have zero major vessel seen and dont have heart disease
# 7.3% people have 1 major blood vessel seen and dont have heart disease
# 7.6% people have 1 major blood vessel seen and  have heart disease

# %%
data['slope'].value_counts(normalize=True)    #the slope of the peak exercise ST(Stress) segment
# Out:
# slope
# 2    0.466887
# 1    0.463576
# 0    0.069536
# Name: proportion, dtype: float64

# %%
data['slope'].value_counts(normalize=True).sort_values(ascending=False).plot(kind='pie',figsize=(10,6),autopct='%1.1f%%',
                                                                        startangle=90,shadow=True)
# Out:
# <Axes: ylabel='proportion'>

# %%
# from the above analysis of slope of the peak exercise ST(Stress) segment have the values 0,1,2 which defines 
# 0 represent no stress 
# 1 represent have mild or moderate stress 
# 2 represent have severe stress 
#  46.7% people have severe stress
# 46.4% people have mild or moderate stress
# 7% people have no stress

# %%
data.groupby(['slope'])['target'].value_counts().sort_values(ascending=False).plot(kind='pie',figsize=(15,7),autopct='%1.1f%%',
                                                                                startangle=90,shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(10, 6))                                         
sns.scatterplot(data=data, x='age', y='slope', hue='slope')
plt.title('Age & slope of the peak exercise ST(Stress) segment')
plt.xlabel('Age')
plt.ylabel('slope of the peak exercise ST(Stress) segment')
plt.show()

# %% [markdown]
# # Correlation

# %%
spearman_coef,p_value = stats.spearmanr(data["age"],data["target"])
print("Spearman Correlation Co-effecient :", spearman_coef, "P-Value of p:",p_value)
# Out:
# Spearman Correlation Co-effecient : -0.2348452903988662 P-Value of p: 3.755240402707282e-05

# %%
# the above analysis shows age and target have weak negative corelation and
#p value very very small and showing they are statistically  significant

# %%
spearman_coef,p_value=stats.spearmanr(data['age'],data['cp'])
print("Spearman correlation Co-effecient :",spearman_coef,"P-value of p:",p_value)
# Out:
# Spearman correlation Co-effecient : -0.08267873445643226 P-value of p: 0.1517721691911801

# %%
#The above analysis shows age and chestpain have a weak neagtive correlation and
#p>0.05 thats means that they are  not statistically  significant

# %%
spearman_coef,p_value=stats.spearmanr(data['age'],data['thalach'])
print("Spearman Correlation co-efficient:",spearman_coef, "p_values of p:",p_value)
# Out:
# Spearman Correlation co-efficient: -0.3617406054947639 p_values of p: 9.105038196180811e-11

# %%
# The above analyis shows age and thalach(maximum heart rate) has a moderate weak  negative correlation and 
# p_values is very less than the threshold and they are staistically significant

# %%
spearman_coef,p_value=stats.spearmanr(data['cp'],data['target'])
print("Spearman Correlation co-efficient:",spearman_coef, "p_values of p:",p_value)
# Out:
# Spearman Correlation co-efficient: 0.45958935474915236 p_values of p: 3.45637064531395e-17

# %%
# The above analysis shows chest pain(cp) and target has a moderate positive correlation
# p values is less than threshold which we consider 0.05 then w can say they are statistically significant

# %%
spearman_coef,p_value=stats.spearmanr(data['fbs'],data['target'])
print("Spearman Correlation co-efficient:",spearman_coef, "p_values of p:",p_value)
# Out:
# Spearman Correlation co-efficient: -0.026825970565970213 p_values of p: 0.6424070490676514

# %%
#The above analysis shows fasting blood sugar and target has a very weak negative correlation
# p>0.05(threshold) then they are not statistically significant

# %%
spearman_coef,p_value=stats.spearmanr(data['cp'],data['restecg'])
print("Spearman Correlation co-efficient:",spearman_coef, "p_values of p:",p_value)
# Out:
# Spearman Correlation co-efficient: 0.06284820434762742 p_values of p: 0.2762717724536547

# %%
# The above analysis shows that chestpain and ecg have a weak positive correlation 
#  p>0.05 and they are not statistically significant

# %%
spearman_coef,p_value=stats.spearmanr(data['cp'],data['chol'])
print("Spearman Correlation co-efficient:",spearman_coef, "p_values of p:",p_value)
# Out:
# Spearman Correlation co-efficient: -0.0767091863049021 p_values of p: 0.18368470068031836

# %%
# The above analysis shows that chestpain and cholestrol have a weak neagtive correlation 
#  p>0.05 and they are not statistically significant

# %%
spearman_coef,p_value=stats.spearmanr(data['exang'],data['target'])
print("Spearman Correlation co-efficient:",spearman_coef, "p_values of p:",p_value)
# Out:
# Spearman Correlation co-efficient: -0.435600761713619 p_values of p: 2.0464675890698477e-15

# %%
 #The above analysis shows exerecise ang(exang) and target has a moderate negative correlation
# p values is less than threshold which we consider 0.05 then w can say they are statistically significant

# %%
spearman_coef,p_value=stats.spearmanr(data['chol'],data['target'])
print("Spearman Correlation co-efficient:",spearman_coef, "p_values of p:",p_value)
# Out:
# Spearman Correlation co-efficient: -0.12814674520035704 p_values of p: 0.02595349396909138

# %%
spearman_coef,p_value=stats.spearmanr(data['cp'],data['thalach'])
print("Spearman Correlation co-efficient:",spearman_coef, "p_values of p:",p_value)
# Out:
# Spearman Correlation co-efficient: 0.30852945896454187 p_values of p: 4.4112521601376117e-08

# %%
spearman_coef,p_value=stats.spearmanr(data['sex'],data['target'])
print("Spearman Correlation co-efficient:",spearman_coef, "p_values of p:",p_value)
# Out:
# Spearman Correlation co-efficient: -0.2836093577958625 p_values of p: 5.402435780432107e-07

# %%
spearman_coef,p_value=stats.spearmanr(data['ca'],data['target'])
print("Spearman Correlation co-efficient:",spearman_coef, "p_values of p:",p_value)
# Out:
# Spearman Correlation co-efficient: -0.026825970565970213 p_values of p: 0.6424070490676514

# %%
spearman_coef,p_value=stats.spearmanr(data['slope'],data['target'])
print("Spearman Correlation co-efficient:",spearman_coef, "p_values of p:",p_value)
# Out:
# Spearman Correlation co-efficient: 0.36939058036624595 p_values of p: 3.388674986608448e-11

# %%
 #The above analysis shows slope  and target has a moderate  positive correlation
# p values is less than threshold which we consider 0.05 then we can say they are statistically significant
